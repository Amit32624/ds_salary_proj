# %%
from typing import Any, Union

import pandas as pd
from pandas import DataFrame, Series
from pandas.io.parsers import TextFileReader

df = pd.read_csv('glassdoor_jobs.csv')
df.head()
# Out:
#                                            Job Title  \
# 0                              Senior Data Scientist
# 1                Data Scientist Technical Specialist
# 2              Scientist - Biology and Biostatistics
# 3                                       Data Analyst
# 4  (FOOD SCIENTIST) Sr. Product Development Techn...
#
#                   Salary Estimate  \
# 0  $109K - $175K (Glassdoor est.)
# 1   $93K - $153K (Glassdoor est.)
# 2                              -1
# 3    $40K - $73K (Glassdoor est.)
# 4                              -1
#
#                                      Job Description  Rating  \
# 0  Job Posting Title\nSenior Data Scientist\nSumm...     3.2
# 1  Technology is constantly changing and our adve...     3.7
# 2  Octave combines deep data with profound empath...    -1.0
# 3  This position will be responsible for the deve...     3.6
# 4  Horizon Food Groupis a strategic bakery and sw...    -1.0
#
#           Company Name        Location  Headquarters                    Size  \
# 0  Big Fish Games\n3.2     Oakland, CA            -1   501 to 1000 Employees
# 1         Peraton\n3.7   Chantilly, VA            -1  1001 to 5000 Employees
# 2    Octave Bioscience  Menlo Park, CA            -1                      -1
# 3   Bell Partners\n3.6     Raleigh, NC            -1  1001 to 5000 Employees
# 4        NEMO'S BAKERY      California            -1                      -1
#
#    Founded               Type of ownership             Industry  \
# 0     2002  Subsidiary or Business Segment          Video Games
# 1     2017               Company - Private  Aerospace & Defense
# 2       -1                              -1                   -1
# 3     1976               Company - Private          Real Estate
# 4       -1                              -1                   -1
#
#                 Sector                    Revenue  Competitors
# 0                Media  $50 to $100 million (USD)           -1
# 1  Aerospace & Defense     $1 to $2 billion (USD)           -1
# 2                   -1                         -1           -1
# 3          Real Estate  $50 to $100 million (USD)           -1
# 4                   -1                         -1           -1

# %%
#Salary parsing
#Company Name text only
#State Field
#Age of company
#Parsing of Job description

df = df[df['Salary Estimate'] != '-1']
salary = df['Salary Estimate'].apply(lambda x:x.split('(')[0])
minus_kd = salary.apply(lambda x:x.replace('K','').replace('$',''))
df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['min_salary'] = minus_kd.apply(lambda x:int(x.split('-')[0]))
df['max_salary'] = minus_kd.apply(lambda x:int(x.split('-')[1]))
df['avg_salary'] = (df.min_salary + df.max_salary)/2

df.head()
print(df.columns)
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'min_salary', 'max_salary', 'avg_salary'],
#       dtype='object')

# %%
#Company name only
df['company_txt'] = df.apply(lambda x:x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3],axis =1)
df_new =df['Location']
#State field
df[['City','State']] = df.Location.str.split(",",expand=True)
#Age of company
df['Age'] = df.Founded.apply(lambda x: x if x <1 else 2020 -x)
df['Job Description'][3]
del df['City']
del df['Competitors']
del df['hourly']
del df['Headquarters']
df.head()
# Out:
#                              Job Title                 Salary Estimate  \
# 0                Senior Data Scientist  $109K - $175K (Glassdoor est.)
# 1  Data Scientist Technical Specialist   $93K - $153K (Glassdoor est.)
# 3                         Data Analyst    $40K - $73K (Glassdoor est.)
# 5                Marketing Scientist I   $48K - $103K (Glassdoor est.)
# 8       Scientist, Product Development    $50K - $93K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Job Posting Title\nSenior Data Scientist\nSumm...     3.2
# 1  Technology is constantly changing and our adve...     3.7
# 3  This position will be responsible for the deve...     3.6
# 5  Valassis is a leader in the marketing technolo...     3.3
# 8  Summary:\nMetagenics is a global lifestyle med...     3.1
#
#           Company Name        Location                    Size  Founded  \
# 0  Big Fish Games\n3.2     Oakland, CA   501 to 1000 Employees     2002
# 1         Peraton\n3.7   Chantilly, VA  1001 to 5000 Employees     2017
# 3   Bell Partners\n3.6     Raleigh, NC  1001 to 5000 Employees     1976
# 5        Valassis\n3.3     Livonia, MI  1001 to 5000 Employees     1970
# 8      Metagenics\n3.1  Gig Harbor, WA    201 to 500 Employees     1983
#
#                 Type of ownership                          Industry  \
# 0  Subsidiary or Business Segment                       Video Games
# 1               Company - Private               Aerospace & Defense
# 3               Company - Private                       Real Estate
# 5               Company - Private           Advertising & Marketing
# 8               Company - Private  Health Care Services & Hospitals
#
#                 Sector                     Revenue  min_salary  max_salary  \
# 0                Media   $50 to $100 million (USD)         109         175
# 1  Aerospace & Defense      $1 to $2 billion (USD)          93         153
# 3          Real Estate   $50 to $100 million (USD)          40          73
# 5    Business Services    Unknown / Non-Applicable          48         103
# 8          Health Care  $100 to $500 million (USD)          50          93
#
#    avg_salary       company_txt State  Age
# 0       142.0  Big Fish Games\n    CA   18
# 1       123.0         Peraton\n    VA    3
# 3        56.5   Bell Partners\n    NC   44
# 5        75.5        Valassis\n    MI   50
# 8        71.5      Metagenics\n    WA   37

# %%
#Python
df['python'] =df['Job Description'].apply(lambda x : 1 if 'python' in x.lower() else 0)
# print(df.python.value_counts())
# R studio
df['r_studio'] =df['Job Description'].apply(lambda x : 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
df.r_studio.value_counts()
#Spark
# R studio
df['spark'] =df['Job Description'].apply(lambda x : 1 if 'spark' in x.lower() else 0)
print(df.spark.value_counts())
#aws
#AWS
df['aws'] =df['Job Description'].apply(lambda x : 1 if 'aws' in x.lower() else 0)
print(df.aws.value_counts())

#Excel
df['excel'] =df['Job Description'].apply(lambda x : 1 if 'excel' in x.lower() else 0)
print(df.excel.value_counts())
# df.drop['Location' == 'Remote']
df.head()
# Out:
# 0    1192
# 1      25
# Name: spark, dtype: int64
# 0    1146
# 1      71
# Name: aws, dtype: int64
# 0    1121
# 1      96
# Name: excel, dtype: int64
#                              Job Title                 Salary Estimate  \
# 0                Senior Data Scientist  $109K - $175K (Glassdoor est.)
# 1  Data Scientist Technical Specialist   $93K - $153K (Glassdoor est.)
# 3                         Data Analyst    $40K - $73K (Glassdoor est.)
# 5                Marketing Scientist I   $48K - $103K (Glassdoor est.)
# 8       Scientist, Product Development    $50K - $93K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Job Posting Title\nSenior Data Scientist\nSumm...     3.2
# 1  Technology is constantly changing and our adve...     3.7
# 3  This position will be responsible for the deve...     3.6
# 5  Valassis is a leader in the marketing technolo...     3.3
# 8  Summary:\nMetagenics is a global lifestyle med...     3.1
#
#           Company Name        Location                    Size  Founded  \
# 0  Big Fish Games\n3.2     Oakland, CA   501 to 1000 Employees     2002
# 1         Peraton\n3.7   Chantilly, VA  1001 to 5000 Employees     2017
# 3   Bell Partners\n3.6     Raleigh, NC  1001 to 5000 Employees     1976
# 5        Valassis\n3.3     Livonia, MI  1001 to 5000 Employees     1970
# 8      Metagenics\n3.1  Gig Harbor, WA    201 to 500 Employees     1983
#
#                 Type of ownership                          Industry  ...  \
# 0  Subsidiary or Business Segment                       Video Games  ...
# 1               Company - Private               Aerospace & Defense  ...
# 3               Company - Private                       Real Estate  ...
# 5               Company - Private           Advertising & Marketing  ...
# 8               Company - Private  Health Care Services & Hospitals  ...
#
#   max_salary avg_salary       company_txt  State  Age python r_studio  spark  \
# 0        175      142.0  Big Fish Games\n     CA   18      0        0      0
# 1        153      123.0         Peraton\n     VA    3      0        0      0
# 3         73       56.5   Bell Partners\n     NC   44      0        0      0
# 5        103       75.5        Valassis\n     MI   50      0        0      0
# 8         93       71.5      Metagenics\n     WA   37      0        0      0
#
#    aws  excel
# 0    0      0
# 1    0      0
# 3    0      0
# 5    0      0
# 8    0      0
#
# [5 rows x 23 columns]

# %%
df_out = df
df_out.to_csv("salary_data_claned.csv",index=False)

# df.out = df.out.drop(['Competitors'],axis=1)

# %%
pd.read_csv('salary_data_claned.csv')
# Out:
#                                 Job Title                 Salary Estimate  \
# 0                   Senior Data Scientist  $109K - $175K (Glassdoor est.)
# 1     Data Scientist Technical Specialist   $93K - $153K (Glassdoor est.)
# 2                            Data Analyst    $40K - $73K (Glassdoor est.)
# 3                   Marketing Scientist I   $48K - $103K (Glassdoor est.)
# 4          Scientist, Product Development    $50K - $93K (Glassdoor est.)
# ...                                   ...                             ...
# 1212                       Data Scientist   $88K - $146K (Glassdoor est.)
# 1213                       Data Scientist   $67K - $112K (Glassdoor est.)
# 1214                       Data Scientist   $98K - $156K (Glassdoor est.)
# 1215                       Data Scientist   $83K - $141K (Glassdoor est.)
# 1216                       Data Scientist   $59K - $105K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Job Posting Title\nSenior Data Scientist\nSumm...     3.2
# 1     Technology is constantly changing and our adve...     3.7
# 2     This position will be responsible for the deve...     3.6
# 3     Valassis is a leader in the marketing technolo...     3.3
# 4     Summary:\nMetagenics is a global lifestyle med...     3.1
# ...                                                 ...     ...
# 1212  In today’s rapidly evolving technology landsca...     4.2
# 1213  Tracing our earliest roots to 1866, VTG has bu...     4.0
# 1214  MobiTV is a video delivery solutions expert co...     2.1
# 1215  Medscape, a division of WebMD, develops and ho...     3.0
# 1216  Overview:\nThe Data Scientist will be an imper...     3.9
#
#              Company Name        Location                    Size  Founded  \
# 0     Big Fish Games\n3.2     Oakland, CA   501 to 1000 Employees     2002
# 1            Peraton\n3.7   Chantilly, VA  1001 to 5000 Employees     2017
# 2      Bell Partners\n3.6     Raleigh, NC  1001 to 5000 Employees     1976
# 3           Valassis\n3.3     Livonia, MI  1001 to 5000 Employees     1970
# 4         Metagenics\n3.1  Gig Harbor, WA    201 to 500 Employees     1983
# ...                   ...             ...                     ...      ...
# 1212       steampunk\n4.2      McLean, VA    201 to 500 Employees     2003
# 1213             VTG\n4.0  Alexandria, VA  1001 to 5000 Employees     1966
# 1214     MobiTV, Inc\n2.1  Emeryville, CA    201 to 500 Employees     1999
# 1215           WebMD\n3.0    New York, NY  1001 to 5000 Employees     2005
# 1216         Invicro\n3.9      Boston, MA    201 to 500 Employees     2008
#
#                    Type of ownership                          Industry  ...  \
# 0     Subsidiary or Business Segment                       Video Games  ...
# 1                  Company - Private               Aerospace & Defense  ...
# 2                  Company - Private                       Real Estate  ...
# 3                  Company - Private           Advertising & Marketing  ...
# 4                  Company - Private  Health Care Services & Hospitals  ...
# ...                              ...                               ...  ...
# 1212               Company - Private                       IT Services  ...
# 1213               Company - Private               Aerospace & Defense  ...
# 1214               Company - Private      Computer Hardware & Software  ...
# 1215                Company - Public                          Internet  ...
# 1216               Company - Private         Biotech & Pharmaceuticals  ...
#
#      max_salary avg_salary       company_txt  State  Age python r_studio  \
# 0           175      142.0  Big Fish Games\n     CA   18      0        0
# 1           153      123.0         Peraton\n     VA    3      0        0
# 2            73       56.5   Bell Partners\n     NC   44      0        0
# 3           103       75.5        Valassis\n     MI   50      0        0
# 4            93       71.5      Metagenics\n     WA   37      0        0
# ...         ...        ...               ...    ...  ...    ...      ...
# 1212        146      117.0       steampunk\n     VA   17      0        0
# 1213        112       89.5             VTG\n     VA   54      0        0
# 1214        156      127.0     MobiTV, Inc\n     CA   21      0        0
# 1215        141      112.0           WebMD\n     NY   15      0        0
# 1216        105       82.0         Invicro\n     MA   12      0        0
#
#       spark  aws  excel
# 0         0    0      0
# 1         0    0      0
# 2         0    0      0
# 3         0    0      0
# 4         0    0      0
# ...     ...  ...    ...
# 1212      0    0      0
# 1213      0    1      0
# 1214      0    0      0
# 1215      0    0      0
# 1216      0    0      0
#
# [1217 rows x 23 columns]
